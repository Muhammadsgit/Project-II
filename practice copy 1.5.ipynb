# %%
import numpy as np
import scipy.stats as stats
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.linear_model import LinearRegression, Lasso
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.metrics import mean_squared_error

# %%
df= pd.read_csv('./datasets/train.csv')
df.shape
# Out:
# (2051, 81)

# %%
df_test= pd.read_csv('./datasets/test.csv')

# %%
missing_val = df.isnull().sum()
missing_val = missing_val[missing_val > 0].sort_values(ascending=False)
missing_val_per = (missing_val / len(df)) * 100
                                
missing_df = pd.DataFrame({'Missing Values': missing_val, 'Percentage': missing_val_per})# Creating a DF to display the missing values and their corresponding percentages
missing_df
# Out:
#                 Missing Values  Percentage
# Pool QC                   2042   99.561190
# Misc Feature              1986   96.830814
# Alley                     1911   93.174061
# Fence                     1651   80.497318
# Fireplace Qu              1000   48.756704
# Lot Frontage               330   16.089712
# Garage Yr Blt              114    5.558264
# Garage Cond                114    5.558264
# Garage Qual                114    5.558264
# Garage Finish              114    5.558264
# Garage Type                113    5.509508
# Bsmt Exposure               58    2.827889
# BsmtFin Type 2              56    2.730375
# Bsmt Cond                   55    2.681619
# Bsmt Qual                   55    2.681619
# BsmtFin Type 1              55    2.681619
# Mas Vnr Area                22    1.072647
# Mas Vnr Type                22    1.072647
# Bsmt Half Bath               2    0.097513
# Bsmt Full Bath               2    0.097513
# Total Bsmt SF                1    0.048757
# Bsmt Unf SF                  1    0.048757
# BsmtFin SF 2                 1    0.048757
# Garage Cars                  1    0.048757
# Garage Area                  1    0.048757
# BsmtFin SF 1                 1    0.048757

# %%
df.drop([ "Pool QC", "Misc Feature","Alley", 'Fence' ], axis=1, inplace=True)

# %%
df['Garage Cond'].fillna('NA', inplace=True)

# %%
df['Lot Frontage'].fillna(df['Lot Frontage'].mean(), inplace=True)

# %%
df['Garage Qual'].fillna('NA', inplace=True)

# %%
df['Garage Finish'].fillna('NA', inplace=True)

# %%
df['Garage Yr Blt'].fillna('NA', inplace=True)

# %%
df['Garage Type'].fillna('NA', inplace=True)

# %%
df['Fireplace Qu'].fillna('NA', inplace=True)

# %%
df['Lot Frontage'].fillna(df['Lot Frontage'].mean(), inplace=True)
df.shape
# Out:
# (2051, 77)

# %%
df.dropna(inplace= True) 
missing_val = df.isnull().sum()
missing_val = missing_val[missing_val > 0].sort_values(ascending=False)
missing_val_per = (missing_val / len(df)) * 100
                                
missing_df = pd.DataFrame({'Missing Values': missing_val, 'Percentage': missing_val_per})# Creating a DF to display the missing values and their corresponding percentages
missing_df
# Out:
# Empty DataFrame
# Columns: [Missing Values, Percentage]
# Index: []

# %% [markdown]
# Successfully removed all Null valuse from the *entire* dataset.

# %%
print(f"df length = {df.shape[0]}")
print(f"Num of unique values in ID column = {df.Id.unique().shape}")
# Out:
# df length = 1969
# Num of unique values in ID column = (1969,)

# %%
df.set_index("Id", inplace=True)

# %%
df.describe()
# Out:
#                 PID  MS SubClass  Lot Frontage       Lot Area  Overall Qual  \
# count  1.969000e+03  1969.000000   1969.000000    1969.000000   1969.000000
# mean   7.125659e+08    57.079736     68.873737   10005.619604      6.154901
# std    1.886729e+08    43.009018     21.241827    6710.225845      1.385860
# min    5.263011e+08    20.000000     21.000000    1300.000000      1.000000
# 25%    5.284562e+08    20.000000     60.000000    7500.000000      5.000000
# 50%    5.354521e+08    50.000000     69.055200    9405.000000      6.000000
# 75%    9.071751e+08    70.000000     78.000000   11492.000000      7.000000
# max    9.241520e+08   190.000000    313.000000  159000.000000     10.000000
#
#        Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  \
# count   1969.000000  1969.000000     1969.000000   1969.000000   1969.000000
# mean       5.583545  1971.814627     1984.434738    101.750127    454.235145
# std        1.105352    30.227788       20.860671    176.432970    461.013988
# min        1.000000  1872.000000     1950.000000      0.000000      0.000000
# 25%        5.000000  1954.000000     1965.000000      0.000000      0.000000
# 50%        5.000000  1975.000000     1993.000000      0.000000    384.000000
# 75%        6.000000  2001.000000     2004.000000    164.000000    741.000000
# max        9.000000  2010.000000     2010.000000   1600.000000   5644.000000
#
#        ...  Wood Deck SF  Open Porch SF  Enclosed Porch   3Ssn Porch  \
# count  ...   1969.000000    1969.000000     1969.000000  1969.000000
# mean   ...     95.962925      47.868969       22.295582     2.699340
# std    ...    129.593082      66.291746       59.698778    25.744208
# min    ...      0.000000       0.000000        0.000000     0.000000
# 25%    ...      0.000000       0.000000        0.000000     0.000000
# 50%    ...      0.000000      28.000000        0.000000     0.000000
# 75%    ...    168.000000      70.000000        0.000000     0.000000
# max    ...   1424.000000     547.000000      432.000000   508.000000
#
#        Screen Porch    Pool Area      Misc Val      Mo Sold      Yr Sold  \
# count   1969.000000  1969.000000   1969.000000  1969.000000  1969.000000
# mean      16.864906     2.212798     51.385983     6.212291  2007.776028
# std       57.797094    36.444159    579.720224     2.747621     1.313282
# min        0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%        0.000000     0.000000      0.000000     4.000000  2007.000000
# 50%        0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%        0.000000     0.000000      0.000000     8.000000  2009.000000
# max      490.000000   800.000000  17000.000000    12.000000  2010.000000
#
#            SalePrice
# count    1969.000000
# mean   182892.861859
# std     78938.334289
# min     12789.000000
# 25%    130000.000000
# 50%    163500.000000
# 75%    214900.000000
# max    611657.000000
#
# [8 rows x 37 columns]

# %%
non_numerical_columns = df.select_dtypes(include=['object']).columns
non_numerical_columns
# Out:
# Index(['MS Zoning', 'Street', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Roof Style', 'Roof Matl',
#        'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type', 'Exter Qual',
#        'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure',
#        'BsmtFin Type 1', 'BsmtFin Type 2', 'Heating', 'Heating QC',
#        'Central Air', 'Electrical', 'Kitchen Qual', 'Functional',
#        'Fireplace Qu', 'Garage Type', 'Garage Yr Blt', 'Garage Finish',
#        'Garage Qual', 'Garage Cond', 'Paved Drive', 'Sale Type'],
#       dtype='object')

# %%
len(non_numerical_columns)
# Out:
# 39

# %%
unique_list = list(set(df.dtypes.to_list()))
unique_list
# Out:
# [dtype('O'), dtype('float64'), dtype('int64')]

# %%
print(f"Shape of df before removing non-numeric columns: {df.shape}")
df_no_non_numeric = df.drop(non_numerical_columns.values, axis=1)
print(f"Shape of df after removing non-numeric columns: {df_no_non_numeric.shape}")
# Out:
# Shape of df before removing non-numeric columns: (1969, 76)
# Shape of df after removing non-numeric columns: (1969, 37)

# %%
plt.figure(figsize=(7, 11))
sns.heatmap(df_no_non_numeric.corr()[['SalePrice']].sort_values('SalePrice', ascending=False),cmap="binary")  
plt.title('Correlation Heatmap of Sales Price')
plt.show()

# %% [markdown]
# ![Alt text](image.png)

# %%
corr = df_no_non_numeric.corr()[['SalePrice']].sort_values('SalePrice', ascending=False)
corr
# Out:
#                  SalePrice
# SalePrice         1.000000
# Overall Qual      0.797646
# Gr Liv Area       0.700919
# Garage Cars       0.651497
# Garage Area       0.651016
# 1st Flr SF        0.630052
# Total Bsmt SF     0.629267
# Year Built        0.567785
# Full Bath         0.548034
# Year Remod/Add    0.541540
# TotRms AbvGrd     0.513530
# Mas Vnr Area      0.510360
# Fireplaces        0.463573
# BsmtFin SF 1      0.410969
# Lot Frontage      0.337108
# Wood Deck SF      0.322905
# Open Porch SF     0.320772
# Lot Area          0.308461
# Half Bath         0.272200
# Bsmt Full Bath    0.269767
# 2nd Flr SF        0.245407
# Bsmt Unf SF       0.162273
# Screen Porch      0.138853
# Bedroom AbvGr     0.129777
# 3Ssn Porch        0.048058
# Pool Area         0.029059
# Mo Sold           0.023693
# BsmtFin SF 2      0.010424
# Misc Val         -0.003469
# Yr Sold          -0.009412
# Low Qual Fin SF  -0.041789
# Bsmt Half Bath   -0.051117
# MS SubClass      -0.087351
# Kitchen AbvGr    -0.091696
# Overall Cond     -0.114526
# Enclosed Porch   -0.138529
# PID              -0.248731

# %% [markdown]
# We set out feature selection thresholds to features that have correlation above 0.6

# %%
feature_seleted = corr[1:7].index.tolist()
feature_seleted
# Out:
# ['Overall Qual',
#  'Gr Liv Area',
#  'Garage Cars',
#  'Garage Area',
#  '1st Flr SF',
#  'Total Bsmt SF']

# %%
# Base line model

X = df_no_non_numeric[feature_seleted]
y = df_no_non_numeric['SalePrice']

print(f"X shape {X.shape}")
print(f"y shape {y.shape}")
# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Instantiate
model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# metrics
rmse = mean_squared_error(y_test, y_pred, squared= False)
r2 = r2_score(y_test, y_pred)

rmse, r2
# Out:
# X shape (1969, 6)
# y shape (1969,)
# (40581.66553524896, 0.7316178447850976)

# %% [markdown]
# ## Features Selection

# %%
df_no_non_numeric['SalePrice']
# Out:
# Id
# 109     130500
# 544     220000
# 153     109000
# 318     174000
# 255     138500
#          ...
# 1587    298751
# 785      82500
# 916     177000
# 639     144000
# 10      189000
# Name: SalePrice, Length: 1969, dtype: int64

# %%
categorical_dummied = pd.get_dummies(df[non_numerical_columns], drop_first= True, dtype="int64")
categorical_dummied
# Out:
#       MS Zoning_FV  MS Zoning_RH  MS Zoning_RL  MS Zoning_RM  Street_Pave  \
# Id
# 109              0             0             1             0            1
# 544              0             0             1             0            1
# 153              0             0             1             0            1
# 318              0             0             1             0            1
# 255              0             0             1             0            1
# ...            ...           ...           ...           ...          ...
# 1587             0             0             1             0            1
# 785              0             0             1             0            1
# 916              0             0             1             0            1
# 639              0             0             1             0            1
# 10               0             0             1             0            1
#
#       Lot Shape_IR2  Lot Shape_IR3  Lot Shape_Reg  Land Contour_HLS  \
# Id
# 109               0              0              0                 0
# 544               0              0              0                 0
# 153               0              0              1                 0
# 318               0              0              1                 0
# 255               0              0              0                 0
# ...             ...            ...            ...               ...
# 1587              0              0              0                 1
# 785               0              0              0                 0
# 916               0              0              1                 0
# 639               0              0              1                 0
# 10                0              0              1                 0
#
#       Land Contour_Low  ...  Paved Drive_P  Paved Drive_Y  Sale Type_CWD  \
# Id                      ...
# 109                  0  ...              0              1              0
# 544                  0  ...              0              1              0
# 153                  0  ...              0              1              0
# 318                  0  ...              0              1              0
# 255                  0  ...              0              0              0
# ...                ...  ...            ...            ...            ...
# 1587                 0  ...              0              1              0
# 785                  0  ...              0              1              0
# 916                  0  ...              0              1              0
# 639                  0  ...              0              1              0
# 10                   0  ...              0              1              0
#
#       Sale Type_Con  Sale Type_ConLD  Sale Type_ConLI  Sale Type_ConLw  \
# Id
# 109               0                0                0                0
# 544               0                0                0                0
# 153               0                0                0                0
# 318               0                0                0                0
# 255               0                0                0                0
# ...             ...              ...              ...              ...
# 1587              0                0                0                0
# 785               0                0                0                0
# 916               0                0                0                0
# 639               0                0                0                0
# 10                0                0                0                0
#
#       Sale Type_New  Sale Type_Oth  Sale Type_WD
# Id
# 109               0              0              1
# 544               0              0              1
# 153               0              0              1
# 318               0              0              1
# 255               0              0              1
# ...             ...            ...            ...
# 1587              0              0              1
# 785               0              0              1
# 916               0              0              1
# 639               0              0              1
# 10                0              0              1
#
# [1969 rows x 299 columns]

# %%
final_df = pd.concat([df_no_non_numeric, categorical_dummied], axis=1)
final_df.head()
# Out:
#            PID  MS SubClass  Lot Frontage  Lot Area  Overall Qual  \
# Id
# 109  533352170           60       69.0552     13517             6
# 544  531379050           60       43.0000     11492             7
# 153  535304180           20       68.0000      7922             5
# 318  916386060           60       73.0000      9802             5
# 255  906425045           50       82.0000     14235             6
#
#      Overall Cond  Year Built  Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  \
# Id
# 109             8        1976            2005         289.0         533.0
# 544             5        1996            1997         132.0         637.0
# 153             7        1953            2007           0.0         731.0
# 318             5        2006            2007           0.0           0.0
# 255             8        1900            1993           0.0           0.0
#
#      ...  Paved Drive_P  Paved Drive_Y  Sale Type_CWD  Sale Type_Con  \
# Id   ...
# 109  ...              0              1              0              0
# 544  ...              0              1              0              0
# 153  ...              0              1              0              0
# 318  ...              0              1              0              0
# 255  ...              0              0              0              0
#
#      Sale Type_ConLD  Sale Type_ConLI  Sale Type_ConLw  Sale Type_New  \
# Id
# 109                0                0                0              0
# 544                0                0                0              0
# 153                0                0                0              0
# 318                0                0                0              0
# 255                0                0                0              0
#
#      Sale Type_Oth  Sale Type_WD
# Id
# 109              0              1
# 544              0              1
# 153              0              1
# 318              0              1
# 255              0              1
#
# [5 rows x 336 columns]

# %%
unique_list = list(set(final_df.dtypes.to_list()))
unique_list
# Out:
# [dtype('float64'), dtype('int64')]

# %%
from dmba import stepwise_selection
from dmba import AIC_score, adjusted_r2_score, regressionSummary

#X = df_no_non_numeric.drop('SalePrice', axis=1)
X = final_df.drop('SalePrice', axis=1)

def train_model(variables):
    if len(variables) == 0:
        return None
    model = LinearRegression()
    model.fit(X[variables], y)
    return model

def score_model(model, variables):
    if len(variables) == 0:
        return AIC_score(y, [y.mean()] * len(y), model, df=1)
    return AIC_score(y, model.predict(X[variables]), model)

best_model, best_variables = stepwise_selection(X.columns, train_model, score_model, 
                                                verbose=True)

print()
print(f'Intercept: {best_model.intercept_:.3f}')
print('Coefficients:')
for name, coef in zip(best_variables, best_model.coef_):
    print(f' {name}: {coef}')

r2 = r2_score(y, best_model.predict(X[best_variables]))
print(f"r2 = {r2}")
# Out:
# Variables: PID, MS SubClass, Lot Frontage, Lot Area, Overall Qual, Overall Cond, Year Built, Year Remod/Add, Mas Vnr Area, BsmtFin SF 1, BsmtFin SF 2, Bsmt Unf SF, Total Bsmt SF, 1st Flr SF, 2nd Flr SF, Low Qual Fin SF, Gr Liv Area, Bsmt Full Bath, Bsmt Half Bath, Full Bath, Half Bath, Bedroom AbvGr, Kitchen AbvGr, TotRms AbvGrd, Fireplaces, Garage Cars, Garage Area, Wood Deck SF, Open Porch SF, Enclosed Porch, 3Ssn Porch, Screen Porch, Pool Area, Misc Val, Mo Sold, Yr Sold, MS Zoning_FV, MS Zoning_RH, MS Zoning_RL, MS Zoning_RM, Street_Pave, Lot Shape_IR2, Lot Shape_IR3, Lot Shape_Reg, Land Contour_HLS, Land Contour_Low, Land Contour_Lvl, Utilities_NoSeWa, Lot Config_CulDSac, Lot Config_FR2, Lot Config_FR3, Lot Config_Inside, Land Slope_Mod, Land Slope_Sev, Neighborhood_Blueste, Neighborhood_BrDale, Neighborhood_BrkSide, Neighborhood_ClearCr, Neighborhood_CollgCr, Neighborhood_Crawfor, Neighborhood_Edwards, Neighborhood_Gilbert, Neighborhood_Greens, Neighborhood_GrnHill, Neighborhood_IDOTRR, Neighborhood_Landmrk, Neighborhood_MeadowV, Neighborhood_Mitchel, Neighborhood_NAmes, Neighborhood_NPkVill, Neighborhood_NWAmes, Neighborhood_NoRidge, Neighborhood_NridgHt, Neighborhood_OldTown, Neighborhood_SWISU, Neighborhood_Sawyer, Neighborhood_SawyerW, Neighborhood_Somerst, Neighborhood_StoneBr, Neighborhood_Timber, Neighborhood_Veenker, Condition 1_Feedr, Condition 1_Norm, Condition 1_PosA, Condition 1_PosN, Condition 1_RRAe, Condition 1_RRAn, Condition 1_RRNe, Condition 1_RRNn, Condition 2_Feedr, Condition 2_Norm, Condition 2_PosA, Condition 2_PosN, Condition 2_RRAe, Condition 2_RRAn, Condition 2_RRNn, Bldg Type_2fmCon, Bldg Type_Duplex, Bldg Type_Twnhs, Bldg Type_TwnhsE, House Style_1.5Unf, House Style_1Story, House Style_2.5Fin, House Style_2.5Unf, House Style_2Story, House Style_SFoyer, House Style_SLvl, Roof Style_Gable, Roof Style_Gambrel, Roof Style_Hip, Roof Style_Mansard, Roof Style_Shed, Roof Matl_CompShg, Roof Matl_Membran, Roof Matl_Tar&Grv, Roof Matl_WdShake, Roof Matl_WdShngl, Exterior 1st_AsphShn, Exterior 1st_BrkComm, Exterior 1st_BrkFace, Exterior 1st_CBlock, Exterior 1st_CemntBd, Exterior 1st_HdBoard, Exterior 1st_ImStucc, Exterior 1st_MetalSd, Exterior 1st_Plywood, Exterior 1st_Stone, Exterior 1st_Stucco, Exterior 1st_VinylSd, Exterior 1st_Wd Sdng, Exterior 1st_WdShing, Exterior 2nd_AsphShn, Exterior 2nd_Brk Cmn, Exterior 2nd_BrkFace, Exterior 2nd_CBlock, Exterior 2nd_CmentBd, Exterior 2nd_HdBoard, Exterior 2nd_ImStucc, Exterior 2nd_MetalSd, Exterior 2nd_Plywood, Exterior 2nd_Stone, Exterior 2nd_Stucco, Exterior 2nd_VinylSd, Exterior 2nd_Wd Sdng, Exterior 2nd_Wd Shng, Mas Vnr Type_BrkFace, Mas Vnr Type_None, Mas Vnr Type_Stone, Exter Qual_Fa, Exter Qual_Gd, Exter Qual_TA, Exter Cond_Fa, Exter Cond_Gd, Exter Cond_Po, Exter Cond_TA, Foundation_CBlock, Foundation_PConc, Foundation_Stone, Foundation_Wood, Bsmt Qual_Fa, Bsmt Qual_Gd, Bsmt Qual_Po, Bsmt Qual_TA, Bsmt Cond_Fa, Bsmt Cond_Gd, Bsmt Cond_Po, Bsmt Cond_TA, Bsmt Exposure_Gd, Bsmt Exposure_Mn, Bsmt Exposure_No, BsmtFin Type 1_BLQ, BsmtFin Type 1_GLQ, BsmtFin Type 1_LwQ, BsmtFin Type 1_Rec, BsmtFin Type 1_Unf, BsmtFin Type 2_BLQ, BsmtFin Type 2_GLQ, BsmtFin Type 2_LwQ, BsmtFin Type 2_Rec, BsmtFin Type 2_Unf, Heating_GasW, Heating_Grav, Heating_OthW, Heating QC_Fa, Heating QC_Gd, Heating QC_Po, Heating QC_TA, Central Air_Y, Electrical_FuseF, Electrical_FuseP, Electrical_Mix, Electrical_SBrkr, Kitchen Qual_Fa, Kitchen Qual_Gd, Kitchen Qual_TA, Functional_Maj2, Functional_Min1, Functional_Min2, Functional_Mod, Functional_Sal, Functional_Sev, Functional_Typ, Fireplace Qu_Fa, Fireplace Qu_Gd, Fireplace Qu_NA, Fireplace Qu_Po, Fireplace Qu_TA, Garage Type_Attchd, Garage Type_Basment, Garage Type_BuiltIn, Garage Type_CarPort, Garage Type_Detchd, Garage Type_NA, Garage Yr Blt_1896.0, Garage Yr Blt_1900.0, Garage Yr Blt_1910.0, Garage Yr Blt_1914.0, Garage Yr Blt_1915.0, Garage Yr Blt_1916.0, Garage Yr Blt_1917.0, Garage Yr Blt_1918.0, Garage Yr Blt_1919.0, Garage Yr Blt ...
# Start: score=49997.33, constant
# Step: score=48008.16, add Overall Qual
# Step: score=47469.29, add Gr Liv Area
# Step: score=47194.19, add BsmtFin SF 1
# Step: score=47035.58, add Garage Cars
# Step: score=46898.62, add Neighborhood_NridgHt
# Step: score=46783.92, add MS SubClass
# Step: score=46669.08, add Neighborhood_StoneBr
# Step: score=46580.33, add Year Built
# Step: score=46492.12, add Bsmt Exposure_Gd
# Step: score=46426.06, add Misc Val
# Step: score=46363.71, add Overall Cond
# Step: score=46308.89, add Garage Yr Blt_2009.0
# Step: score=46265.31, add Neighborhood_NoRidge
# Step: score=46218.92, add Screen Porch
# Step: score=46174.39, add Neighborhood_Crawfor
# Step: score=46139.25, add Lot Shape_IR3
# Step: score=46107.27, add Lot Area
# Step: score=46072.39, add Neighborhood_Somerst
# Step: score=46044.58, add Bsmt Qual_Gd
# Step: score=45990.04, add Bsmt Qual_TA
# Step: score=45958.31, add Bsmt Qual_Fa
# Step: score=45924.74, add Exterior 1st_BrkFace
# Step: score=45897.91, add Neighborhood_GrnHill
# Step: score=45874.44, add Bsmt Exposure_No
# Step: score=45854.85, add Bldg Type_2fmCon
# Step: score=45838.45, add Year Remod/Add
# Step: score=45822.38, add Wood Deck SF
# Step: score=45807.54, add Exterior 1st_CemntBd
# Step: score=45792.03, add Mas Vnr Area
# Step: score=45779.38, add Bsmt Full Bath
# Step: score=45766.83, add Fireplaces
# Step: score=45751.79, add Functional_Typ
# Step: score=45737.95, add Exter Qual_TA
# Step: score=45693.20, add Exter Qual_Gd
# Step: score=45664.02, add Exter Qual_Fa
# Step: score=45650.78, add Condition 1_Norm
# Step: score=45635.36, add Condition 1_PosN
# Step: score=45625.48, add Pool Area
# Step: score=45613.81, add Garage Qual_Gd
# Step: score=45604.07, add Roof Matl_WdShngl
# Step: score=45596.04, add Condition 2_RRAe
# Step: score=45588.52, add Land Contour_HLS
# Step: score=45580.81, add Bsmt Exposure_Mn
# Step: score=45573.84, add Lot Frontage
# Step: score=45566.83, add Neighborhood_Edwards
# Step: score=45559.84, add Garage Type_NA
# Step: score=45553.13, add Heating QC_TA
# Step: score=45547.49, add Roof Style_Mansard
# Step: score=45541.82, add Functional_Sev
# Step: score=45536.11, add Condition 1_PosA
# Step: score=45531.32, add Garage Yr Blt_2006.0
# Step: score=45526.64, add Exterior 1st_Stucco
# Step: score=45521.71, add Land Contour_Lvl
# Step: score=45516.57, add Garage Finish_RFn
# Step: score=45512.08, add Kitchen AbvGr
# Step: score=45506.45, add Full Bath
# Step: score=45501.41, add Kitchen Qual_Gd
# Step: score=45471.23, add Kitchen Qual_TA
# Step: score=45446.13, add Kitchen Qual_Fa
# Step: score=45442.92, add Exterior 2nd_VinylSd
# Step: score=45439.61, add BsmtFin Type 1_Unf
# Step: score=45435.77, add Heating_OthW
# Step: score=45433.16, add MS Zoning_RL
# Step: score=45429.58, add PID
# Step: score=45427.21, add Utilities_NoSeWa
# Step: score=45424.95, add Roof Matl_CompShg
# Step: score=45406.14, add Roof Matl_Tar&Grv
# Step: score=45346.47, add Roof Matl_WdShake
# Step: score=45140.02, add Roof Matl_Membran
# Step: score=45122.93, add Total Bsmt SF
# Step: score=45115.33, add Sale Type_New
# Step: score=45110.30, add Foundation_PConc
# Step: score=45105.65, add Garage Yr Blt_2008.0
# Step: score=45101.11, add Lot Config_CulDSac
# Step: score=45096.49, add Neighborhood_BrkSide
# Step: score=45091.76, add Neighborhood_NPkVill
# Step: score=45087.49, add 2nd Flr SF
# Step: score=45082.84, add Garage Area
# Step: score=45078.62, add BsmtFin Type 2_GLQ
# Step: score=45075.57, add Land Slope_Sev
# Step: score=45072.54, add House Style_2.5Unf
# Step: score=45069.67, add Exterior 1st_MetalSd
# Step: score=45066.83, add Neighborhood_BrDale
# Step: score=45063.94, add Exterior 2nd_Wd Sdng
# Step: score=45061.28, add Paved Drive_Y
# Step: score=45059.22, add Bedroom AbvGr
# Step: score=45057.27, remove BsmtFin Type 1_Unf
# Step: score=45055.56, remove Exterior 1st_Stucco
# Step: score=45053.93, add Functional_Min1
# Step: score=45050.90, add Functional_Min2
# Step: score=45049.51, add Garage Yr Blt_1922.0
# Step: score=45048.38, remove Lot Shape_IR3
# Step: score=45047.24, add Garage Yr Blt_1958.0
# Step: score=45045.81, add Bsmt Half Bath
# Step: score=45044.89, add Garage Yr Blt_2001.0
# Step: score=45043.95, add Heating_Grav
# Step: score=45043.24, add Sale Type_Con
# Step: score=45042.29, add Garage Yr Blt_1975.0
# Step: score=45041.11, add Garage Yr Blt_1977.0
# Step: score=45040.27, add Garage Yr Blt_2007.0
# Step: score=45039.86, add Exterior 2nd_AsphShn
# Step: score=45039.46, add Exterior 1st_BrkComm
# Step: score=45039.18, add Sale Type_CWD
# Step: score=45038.93, add Lot Config_FR3
# Step: score=45038.75, add BsmtFin Type 1_GLQ
# Step: score=45038.69, add Street_Pave
# Step: score=45038.66, add Roof Style_Hip
# Step: score=45038.30, add Exterior 2nd_BrkFace
# Step: score=45038.30, add Mas Vnr Type_None
# Step: score=45038.30, unchanged None
#
# Intercept: -1324680.054
# Coefficients:
#  Overall Qual: 6869.705981565212
#  Gr Liv Area: 43.00386545732779
#  BsmtFin SF 1: 14.243330118701138
#  Garage Cars: 4386.143788928659
#  Neighborhood_NridgHt: 30384.826311142566
#  MS SubClass: -178.25650224698018
#  Neighborhood_StoneBr: 46589.482070697115
#  Year Built: 295.3035007724081
#  Bsmt Exposure_Gd: 11361.97385455759
#  Misc Val: -13.1283009590843
#  Overall Cond: 5347.484170085494
#  Garage Yr Blt_2009.0: 31464.379195781003
#  Neighborhood_NoRidge: 32742.61814949839
#  Screen Porch: 63.867550440468676
#  Neighborhood_Crawfor: 14464.830692997679
#  Lot Area: 0.7175247221130121
#  Neighborhood_Somerst: 18216.190248842697
#  Bsmt Qual_Gd: -13811.592012670046
#  Bsmt Qual_TA: -11619.617338050275
#  Bsmt Qual_Fa: -9125.193891043626
#  Exterior 1st_BrkFace: 24528.553791666647
#  Neighborhood_GrnHill: 143866.01561291819
#  Bsmt Exposure_No: -7605.839826828393
#  Bldg Type_2fmCon: 15634.979349275825
#  Year Remod/Add: 72.4200479741503
#  Wood Deck SF: 13.640767306460475
#  Exterior 1st_CemntBd: 6813.338052680162
#  Mas Vnr Area: 17.769913329708288
#  Bsmt Full Bath: 4135.663275749666
#  Fireplaces: 4116.863542078262
#  Functional_Typ: 19454.12656430227
#  Exter Qual_TA: -27820.18388333455
#  Exter Qual_Gd: -23992.844275871044
#  Exter Qual_Fa: -24932.038659172653
#  Condition 1_Norm: 9146.08389200921
#  Condition 1_PosN: 14442.622269829166
#  Pool Area: 33.01413140731347
#  Garage Qual_Gd: 22677.46868518704
#  Roof Matl_WdShngl: 645328.1968361316
#  Condition 2_RRAe: 115400.04304340584
#  Land Contour_HLS: 12435.772455611897
#  Bsmt Exposure_Mn: -7640.277828912708
#  Lot Frontage: 89.23283912808847
#  Neighborhood_Edwards: -6713.900817263939
#  Garage Type_NA: 10755.09637589936
#  Heating QC_TA: -3681.3075796684834
#  Roof Style_Mansard: -25875.273407189194
#  Functional_Sev: -34436.939349105305
#  Condition 1_PosA: 16437.052710131265
#  Garage Yr Blt_2006.0: 6715.761644450325
#  Land Contour_Lvl: 4654.0467203445405
#  Garage Finish_RFn: -3416.354528972558
#  Kitchen AbvGr: -13838.074621244354
#  Full Bath: 3516.609223229342
#  Kitchen Qual_Gd: -21850.67113406076
#  Kitchen Qual_TA: -22877.54419635933
#  Kitchen Qual_Fa: -24235.56476057476
#  Exterior 2nd_VinylSd: 4115.325602251077
#  Heating_OthW: -37095.313041391644
#  MS Zoning_RL: 4885.913991321072
#  PID: 8.146233085426502e-06
#  Utilities_NoSeWa: -45627.54592387371
#  Roof Matl_CompShg: 594288.2479062073
#  Roof Matl_Tar&Grv: 594416.3216695082
#  Roof Matl_WdShake: 601823.7564112345
#  Roof Matl_Membran: 640878.5922186578
#  Total Bsmt SF: 16.629480714897
#  Sale Type_New: 8804.72133467633
#  Foundation_PConc: 4583.348264614185
#  Garage Yr Blt_2008.0: 9293.171507347419
#  Lot Config_CulDSac: 6625.612784024452
#  Neighborhood_BrkSide: 7238.485989697111
#  Neighborhood_NPkVill: 22448.697465352812
#  2nd Flr SF: 10.694968259413145
#  Garage Area: 14.679985122082144
#  BsmtFin Type 2_GLQ: 13360.256728442171
#  Land Slope_Sev: -21379.889676347488
#  House Style_2.5Unf: 13740.096784818574
#  Exterior 1st_MetalSd: 4401.38908016276
#  Neighborhood_BrDale: 14960.028610491674
#  Exterior 2nd_Wd Sdng: 2832.380382756665
#  Paved Drive_Y: 4371.162899217485
#  Bedroom AbvGr: -1534.2926325128399
#  Functional_Min1: 12851.818548114108
#  Functional_Min2: 11754.943550993967
#  Garage Yr Blt_1922.0: 15069.660781955183
#  Garage Yr Blt_1958.0: 8809.78344579599
#  Bsmt Half Bath: -4433.75077285499
#  Garage Yr Blt_2001.0: 7503.446162414681
#  Heating_Grav: -17342.804559718476
#  Sale Type_Con: 22144.32427815418
#  Garage Yr Blt_1975.0: -8871.510138935024
#  Garage Yr Blt_1977.0: -6141.81114397024
#  Garage Yr Blt_2007.0: -5159.705443219292
#  Exterior 2nd_AsphShn: 21401.188458370652
#  Exterior 1st_BrkComm: -19602.291762678957
#  Sale Type_CWD: 10990.361825714015
#  Lot Config_FR3: -12051.628269640349
#  BsmtFin Type 1_GLQ: 2487.3047834906006
#  Street_Pave: 12987.014891053102
#  Roof Style_Hip: 2371.8864473658377
#  Exterior 2nd_BrkFace: -8980.529122535278
#  Mas Vnr Type_None: 2158.3398735472792
# r2 = 0.9274279255905898

# %%
regressionSummary(y, best_model.predict(X[best_variables]))
# Out:
# Regression statistics
#
#                       Mean Error (ME) : -0.0000
#        Root Mean Squared Error (RMSE) : 21259.9586
#             Mean Absolute Error (MAE) : 13872.2887
#           Mean Percentage Error (MPE) : -0.8861
# Mean Absolute Percentage Error (MAPE) : 8.3089

# %%
print(f"X.columns = {X.columns}")
print(f"best_variables = {best_variables}")
print(f"len(X.columns.value) = {len(X.columns.values)}")
print(f"len(best_variables) = {len(best_variables)}")
# Out:
# X.columns = Index(['PID', 'MS SubClass', 'Lot Frontage', 'Lot Area', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Mas Vnr Area',
#        'BsmtFin SF 1',
#        ...
#        'Paved Drive_P', 'Paved Drive_Y', 'Sale Type_CWD', 'Sale Type_Con',
#        'Sale Type_ConLD', 'Sale Type_ConLI', 'Sale Type_ConLw',
#        'Sale Type_New', 'Sale Type_Oth', 'Sale Type_WD '],
#       dtype='object', length=335)
# best_variables = ['Overall Qual', 'Gr Liv Area', 'BsmtFin SF 1', 'Garage Cars', 'Neighborhood_NridgHt', 'MS SubClass', 'Neighborhood_StoneBr', 'Year Built', 'Bsmt Exposure_Gd', 'Misc Val', 'Overall Cond', 'Garage Yr Blt_2009.0', 'Neighborhood_NoRidge', 'Screen Porch', 'Neighborhood_Crawfor', 'Lot Area', 'Neighborhood_Somerst', 'Bsmt Qual_Gd', 'Bsmt Qual_TA', 'Bsmt Qual_Fa', 'Exterior 1st_BrkFace', 'Neighborhood_GrnHill', 'Bsmt Exposure_No', 'Bldg Type_2fmCon', 'Year Remod/Add', 'Wood Deck SF', 'Exterior 1st_CemntBd', 'Mas Vnr Area', 'Bsmt Full Bath', 'Fireplaces', 'Functional_Typ', 'Exter Qual_TA', 'Exter Qual_Gd', 'Exter Qual_Fa', 'Condition 1_Norm', 'Condition 1_PosN', 'Pool Area', 'Garage Qual_Gd', 'Roof Matl_WdShngl', 'Condition 2_RRAe', 'Land Contour_HLS', 'Bsmt Exposure_Mn', 'Lot Frontage', 'Neighborhood_Edwards', 'Garage Type_NA', 'Heating QC_TA', 'Roof Style_Mansard', 'Functional_Sev', 'Condition 1_PosA', 'Garage Yr Blt_2006.0', 'Land Contour_Lvl', 'Garage Finish_RFn', 'Kitchen AbvGr', 'Full Bath', 'Kitchen Qual_Gd', 'Kitchen Qual_TA', 'Kitchen Qual_Fa', 'Exterior 2nd_VinylSd', 'Heating_OthW', 'MS Zoning_RL', 'PID', 'Utilities_NoSeWa', 'Roof Matl_CompShg', 'Roof Matl_Tar&Grv', 'Roof Matl_WdShake', 'Roof Matl_Membran', 'Total Bsmt SF', 'Sale Type_New', 'Foundation_PConc', 'Garage Yr Blt_2008.0', 'Lot Config_CulDSac', 'Neighborhood_BrkSide', 'Neighborhood_NPkVill', '2nd Flr SF', 'Garage Area', 'BsmtFin Type 2_GLQ', 'Land Slope_Sev', 'House Style_2.5Unf', 'Exterior 1st_MetalSd', 'Neighborhood_BrDale', 'Exterior 2nd_Wd Sdng', 'Paved Drive_Y', 'Bedroom AbvGr', 'Functional_Min1', 'Functional_Min2', 'Garage Yr Blt_1922.0', 'Garage Yr Blt_1958.0', 'Bsmt Half Bath', 'Garage Yr Blt_2001.0', 'Heating_Grav', 'Sale Type_Con', 'Garage Yr Blt_1975.0', 'Garage Yr Blt_1977.0', 'Garage Yr Blt_2007.0', 'Exterior 2nd_AsphShn', 'Exterior 1st_BrkComm', 'Sale Type_CWD', 'Lot Config_FR3', 'BsmtFin Type 1_GLQ', 'Street_Pave', 'Roof Style_Hip', 'Exterior 2nd_BrkFace', 'Mas Vnr Type_None']
# len(X.columns.value) = 335
# len(best_variables) = 103

# %%
df_test= pd.read_csv('./datasets/test.csv')
missing_val = df_test.isnull().sum()
missing_val = missing_val[missing_val > 0].sort_values(ascending=False)
missing_val_per = (missing_val / len(df_test)) * 100
                                
missing_df = pd.DataFrame({'Missing Values': missing_val, 'Percentage': missing_val_per})# Creating a DF to display the missing values and their corresponding percentages
df_test.drop([ "Pool QC", "Misc Feature","Alley", 'Fence' ], axis=1, inplace=True)
df_test['Garage Cond'].fillna('NA', inplace=True)
df_test['Lot Frontage'].fillna(df_test['Lot Frontage'].mean(), inplace=True)
df_test['Garage Qual'].fillna('NA', inplace=True)
df_test['Garage Finish'].fillna('NA', inplace=True)
df_test['Garage Yr Blt'].fillna('NA', inplace=True)
df_test['Garage Type'].fillna('NA', inplace=True)
df_test['Fireplace Qu'].fillna('NA', inplace=True)
df_test['Lot Frontage'].fillna(df_test['Lot Frontage'].mean(), inplace=True)

df_test.dropna(inplace= True) 
missing_val = df_test.isnull().sum()
missing_val = missing_val[missing_val > 0].sort_values(ascending=False)
missing_val_per = (missing_val / len(df_test)) * 100
                                
missing_df = pd.DataFrame({'Missing Values': missing_val, 'Percentage': missing_val_per})# Creating a DF to display the missing values and their corresponding percentages
missing_df
# Out:
# Empty DataFrame
# Columns: [Missing Values, Percentage]
# Index: []

# %%
df_test.set_index("Id", inplace=True)

# %%
print(f"Shape of df before removing non-numeric columns: {df_test.shape}")
df_no_non_numeric = df_test.drop(non_numerical_columns.values, axis=1)
print(f"Shape of df after removing non-numeric columns: {df_no_non_numeric.shape}")
# Out:
# Shape of df before removing non-numeric columns: (851, 75)
# Shape of df after removing non-numeric columns: (851, 36)

# %%
categorical_dummied = pd.get_dummies(df_test[non_numerical_columns.values], drop_first= True)
categorical_dummied
# Out:
#       MS Zoning_FV  MS Zoning_I (all)  MS Zoning_RH  MS Zoning_RL  \
# Id
# 2658             0                  0             0             0
# 2718             0                  0             0             1
# 2414             0                  0             0             1
# 1989             0                  0             0             0
# 625              0                  0             0             1
# ...            ...                ...           ...           ...
# 1662             0                  0             0             1
# 1234             0                  0             0             1
# 1373             0                  0             0             1
# 1672             0                  0             0             1
# 1939             0                  0             0             1
#
#       MS Zoning_RM  Street_Pave  Lot Shape_IR2  Lot Shape_IR3  Lot Shape_Reg  \
# Id
# 2658             1            1              0              0              1
# 2718             0            1              0              0              0
# 2414             0            1              0              0              0
# 1989             1            1              0              0              1
# 625              0            1              0              0              0
# ...            ...          ...            ...            ...            ...
# 1662             0            1              0              0              1
# 1234             0            1              0              0              1
# 1373             0            1              0              0              1
# 1672             0            1              0              0              1
# 1939             0            1              0              0              1
#
#       Land Contour_HLS  ...  Paved Drive_Y  Sale Type_CWD  Sale Type_Con  \
# Id                      ...
# 2658                 0  ...              1              0              0
# 2718                 0  ...              1              0              0
# 2414                 0  ...              1              0              0
# 1989                 0  ...              0              0              0
# 625                  0  ...              1              0              0
# ...                ...  ...            ...            ...            ...
# 1662                 0  ...              1              0              0
# 1234                 0  ...              1              0              0
# 1373                 0  ...              1              0              0
# 1672                 0  ...              1              0              0
# 1939                 0  ...              1              0              0
#
#       Sale Type_ConLD  Sale Type_ConLI  Sale Type_ConLw  Sale Type_New  \
# Id
# 2658                0                0                0              0
# 2718                0                0                0              0
# 2414                0                0                0              1
# 1989                0                0                0              0
# 625                 0                0                0              0
# ...               ...              ...              ...            ...
# 1662                0                0                0              0
# 1234                0                0                0              0
# 1373                0                0                0              0
# 1672                0                0                0              0
# 1939                0                0                0              0
#
#       Sale Type_Oth  Sale Type_VWD  Sale Type_WD
# Id
# 2658              0              0              1
# 2718              0              0              1
# 2414              0              0              0
# 1989              0              0              1
# 625               0              0              1
# ...             ...            ...            ...
# 1662              0              0              1
# 1234              0              0              1
# 1373              0              0              1
# 1672              0              0              1
# 1939              0              0              1
#
# [851 rows x 278 columns]

# %%
final_df = pd.concat([df_no_non_numeric, categorical_dummied], axis=1)
final_df.head()
# Out:
#             PID  MS SubClass  Lot Frontage  Lot Area  Overall Qual  \
# Id
# 2658  902301120          190     69.000000      9142             6
# 2718  905108090           90     69.545961      9662             5
# 2414  528218130           60     58.000000     17104             7
# 1989  902207150           30     60.000000      8520             5
# 625   535105100           20     69.545961      9500             6
#
#       Overall Cond  Year Built  Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  \
# Id
# 2658             8        1910            1950           0.0             0
# 2718             4        1977            1977           0.0             0
# 2414             5        2006            2006           0.0           554
# 1989             6        1923            2006           0.0             0
# 625              5        1963            1963         247.0           609
#
#       ...  Paved Drive_Y  Sale Type_CWD  Sale Type_Con  Sale Type_ConLD  \
# Id    ...
# 2658  ...              1              0              0                0
# 2718  ...              1              0              0                0
# 2414  ...              1              0              0                0
# 1989  ...              0              0              0                0
# 625   ...              1              0              0                0
#
#       Sale Type_ConLI  Sale Type_ConLw  Sale Type_New  Sale Type_Oth  \
# Id
# 2658                0                0              0              0
# 2718                0                0              0              0
# 2414                0                0              1              0
# 1989                0                0              0              0
# 625                 0                0              0              0
#
#       Sale Type_VWD  Sale Type_WD
# Id
# 2658              0              1
# 2718              0              1
# 2414              0              0
# 1989              0              1
# 625               0              1
#
# [5 rows x 314 columns]

# %%
X = final_df[best_variables]
# Predict SalePrice using the trained model
predicted_sale_price = best_model.predict(X)

# Create a DataFrame for the predictions
predictions_df = pd.DataFrame({
    'Id': final_df['Id'],
    'SalePrice': predicted_sale_price
})

# Save the predictions to a CSV file
output_path = "./datasets/predicted_sale_prices_production_model_FINAL.csv"
predictions_df.to_csv(output_path, index=False)

output_path
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_55752\1727294768.py in <module>
# ----> 1 X = final_df[best_variables]
#       2 # Predict SalePrice using the trained model
#       3 predicted_sale_price = best_model.predict(X)
#       4
#       5 # Create a DataFrame for the predictions
#
# c:\Users\muham\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# c:\Users\muham\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#    5798         keyarr = self.take(indexer)
#
# c:\Users\muham\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5857
#    5858             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5859             raise KeyError(f"{not_found} not in index")
#    5860
#    5861     @overload
#
# KeyError: "['Neighborhood_GrnHill', 'Condition 2_RRAe', 'Functional_Sev', 'Heating_OthW', 'Utilities_NoSeWa', 'Roof Matl_CompShg', 'Roof Matl_Membran', 'Exterior 2nd_AsphShn'] not in index"

# %%
missing_val = df_test.isnull().sum()
missing_val = missing_val[missing_val > 0].sort_values(ascending=False)
missing_val_per = (missing_val / len(df)) * 100
                                
missing_df = pd.DataFrame({'Missing Values': missing_val, 'Percentage': missing_val_per})# Creating a DF to display the missing values and their corresponding percentages
missing_df
